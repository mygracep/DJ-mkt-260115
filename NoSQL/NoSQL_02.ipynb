# %%
# pymongo 설치여부!!
# !pip install pymongo

# %%
from pymongo import MongoClient

client = MongoClient("mongodb://localhost:27017")

db = client["sample_mflix"]
collections = db.list_collection_names()

for collection in collections :
    print(collection)
# Out:
# comments
# sessions
# users
# theaters
# movies

# %%
movies = db.movies
print(movies)
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'sample_mflix'), 'movies')

# %%
from pymongo import MongoClient

client = MongoClient("mongodb://localhost:27017")

db = client["test"]
users = db.users

data = {"name": "David", "age": 20}
result = users.insert_one(data)

print(result)
# Out:
# InsertOneResult(ObjectId('69bce0e22f68b6c2db6f5143'), acknowledged=True)

# %%
client.close() # 메모리 누수를 방지하기 위한 목적으로 close() 사용!

# %%
with MongoClient("mongodb://localhost:27017") as client :
    db = client["test"]
    users = db.users
    data = {"name": "David", "age": 20}
    result = users.insert_one(data)

# %%
with MongoClient("mongodb://localhost:27017") as client :
    db = client["test"]
    users = db.users
    data = [
    {"name": "Kim", "age": 25},
    {"name": "Lee", "age": 35},
    {"name": "Park", "age": 40}
    ]
    result = users.insert_many(data)

# %%
client = MongoClient("mongodb://localhost:27017")

db = client["test"]
collection = db.users

# document = collection.find_one({"name": "David"})
# document = collection.find({"name": "David"})

documents = collection.find()

for document in documents :
    print(document)
# Out:
# {'_id': ObjectId('69bce2342f68b6c2db6f5145'), 'name': 'David', 'age': 20}
# {'_id': ObjectId('69bceeea2f68b6c2db6f514a'), 'name': 'Kim', 'age': 25}
# {'_id': ObjectId('69bceeea2f68b6c2db6f514b'), 'name': 'Lee', 'age': 35}
# {'_id': ObjectId('69bceeea2f68b6c2db6f514c'), 'name': 'Park', 'age': 40}

# %%
client = MongoClient("mongodb://localhost:27017")

db = client["test"]
collection = db.users
filter = {"name": "David"}
update = {"$set":{"age": 30}}

result = collection.update_one(filter, update)
print(result, result.matched_count, result.modified_count)
# Out:
# UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True) 1 1

# %%
client = MongoClient("mongodb://localhost:27017")

db = client["test"]
collection = db.users

filter = {"age": {"$gt": 30}}
update = {"$set": {"is_available": True}}
result = collection.update_many(filter, update)

print("matched Count :", result.matched_count, "modified Count :", result.modified_count)
# Out:
# matched Count : 2 modified Count : 2

# %%
client = MongoClient("mongodb://localhost:27017")

db = client["test"]
collection = db.users

filter = {"name": "Park"}
result = collection.delete_one(filter)

print("Deleted Count:", result.deleted_count)
# Out:
# Deleted Count: 1

# %%
client = MongoClient("mongodb://localhost:27017")

db = client["test"]
collection = db.users

filter = {"age": {"$lte": 30}}
result = collection.delete_many(filter)
print("Deleted Count:", result.deleted_count)
# Out:
# Deleted Count: 2

# %%
client.close()
