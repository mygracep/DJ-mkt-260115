# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go

df = pd.DataFrame(np.random.rand(10, 2), columns=["A", "B"]) # 0이상 1미만, 실수자료형값을 난수의 형태로 생성

fig = go.Figure()

fig.add_trace(
    go.Bar(
        x=df.index, y=df["A"], name="A", text=df["A"], textposition="auto", texttemplate="%{y:.2f}"
    )
)

fig.add_trace(
    go.Bar(
        x=df.index, y=df["B"], name="B", text=df["B"], textposition="auto", texttemplate="%{y:.2f}"
    )
)

fig.show()

# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go

df = pd.DataFrame({
    "A": np.random.randint(10, 50, size=10), # 0 ~ 9 사이의 정수를 난수값으로 생성
    "B": np.random.randint(10, 50, size=10)
})

fig = go.Figure()

fig.add_trace(
    go.Bar(
        x=df.index, y=df["A"], name="A", text=df["A"], textposition="auto", texttemplate="%{y:.2f}"
    )
)

fig.add_trace(
    go.Bar(
        x=df.index, y=df["B"], name="B", text=df["B"], textposition="auto", texttemplate="%{y:.2f}"
    )
)

fig.update_layout(
    {
        "title": {
            "text": "Graph with <b>go.Bar</b>",
            "x": 0.5,
            "y": 0.9,
            "font": {
                "size": 20
            }
        },
        "showlegend": True,
        "xaxis": {
            "title": "index number",
            "showticklabels": True,
            "dtick": 1
        },
        "yaxis": {
            "title": "randint"
        },
        "autosize": False,
        "width": 800,
        "height": 400
    }
)

fig.show()
